# %%
# import custom modules
from src.data_processing import load_data, clean_data, preprocess_data, check_missing_values
from src.eda import review_data_structure, calculate_descriptive_statistics
from src.data_visualization import data_comparison, outlier_detection, create_visualizations, plot_boxplot, plot_scatter, plot_histogram

# %%
# create a file path
file_path = "../data/raw/MachineLearningRating_v3.txt"

# %%
# Load the dataset
df = load_data(file_path)

# %%
# show the first 5 rows of the dataset
df.head()
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %%
check_missing_values(df)
# Out:
# Missing Values Summary:
#                          Missing Values  Percentage
# Bank                             145961   14.594670
# AccountType                       40232    4.022806
# MaritalStatus                      8259    0.825819
# Gender                             9536    0.953507
# mmcode                              552    0.055195
# VehicleType                         552    0.055195
# make                                552    0.055195
# Model                               552    0.055195
# Cylinders                           552    0.055195
# cubiccapacity                       552    0.055195
# kilowatts                           552    0.055195
# bodytype                            552    0.055195
# NumberOfDoors                       552    0.055195
# VehicleIntroDate                    552    0.055195
# CustomValueEstimate              779642   77.956560
# CapitalOutstanding                    2    0.000200
# NewVehicle                       153295   15.327998
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
# ...

# %%
# clean the data
df = clean_data(df)

# %%
# preprocess the data
df = preprocess_data(df)

# %%
# check the data structure
check_missing_values(df)
# Out:
# Missing Values Summary:
# Empty DataFrame
# Columns: [Missing Values, Percentage]
# Index: []

# %%
# see the first 5 rows of the dataset
df.head()
# Out:
#    UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0               145249     12827       2015-03-01             True
# 1               145249     12827       2015-05-01             True
# 2               145249     12827       2015-07-01             True
# 3               145255     12827       2015-05-01             True
# 4               145255     12827       2015-07-01             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %%
# review the data structure
df = review_data_structure(df)
# Out:
# Data Types of Each Column:
# UnderwrittenCoverID                  int64
# PolicyID                             int64
# TransactionMonth            datetime64[ns]
# IsVATRegistered                       bool
# Citizenship                         object
# LegalType                           object
# Title                               object
# Language                            object
# Bank                                object
# AccountType                         object
# MaritalStatus                       object
# Gender                              object
# Country                             object
# Province                            object
# PostalCode                           int64
# MainCrestaZone                      object
# SubCrestaZone                       object
# ItemType                            object
# mmcode                             float64
# VehicleType                         object
# RegistrationYear                     int64
# ...

# %%
# calculate descriptive statistics and variability for numerical features
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# %%
descriptive_stats, variability = calculate_descriptive_statistics(df, numeric_columns)
# Out:
# Descriptive Statistics for Numerical Features:
#        UnderwrittenCoverID       PolicyID     PostalCode        mmcode  \
# count        716208.000000  716208.000000  716208.000000  7.162080e+05
# mean         117470.870461    8935.228671    3117.288453  5.542884e+07
# std           58186.085139    4975.039752    2612.415769  1.292904e+07
# min              13.000000      14.000000       1.000000  4.042080e+06
# 25%           78362.000000    5879.000000    1059.000000  6.005692e+07
# 50%          113764.000000    7755.000000    2000.000000  6.005841e+07
# 75%          144552.000000   11800.000000    4340.000000  6.005842e+07
# max          301133.000000   23241.000000    9870.000000  6.503072e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count     716208.000000  716208.000000  716208.000000  716208.000000
# mean        2009.973019       4.046009    2466.762554      96.215948
# std            3.396701       0.267560     413.055911      19.132682
# ...

# %%
# create visualizations
create_visualizations(df)

# %%
# compare trends over geography (Province or PostalCode)
data_comparison(df)

# %%
# detect outliers using box plots for numerical columns
outlier_detection(df, numeric_columns)

# %%
# plot boxplot
plot_boxplot(df, column='TotalPremium')

# %%
# plot boxplot for TotalClaims
plot_boxplot(df, column='TotalClaims')

# %%
# plot boxplot for PostalCode
plot_boxplot(df, column='PostalCode')

# %%
# plot scatter plot for TotalPremium vs TotalClaims
plot_scatter(df, x_column='TotalPremium', y_column='TotalClaims')

# %%
# scatter plot for PostalCode vs TotalPremium
plot_scatter(df, x_column='PostalCode', y_column='TotalPremium')

# %%
# scatter plot for PostalCode vs TotalClaims
plot_scatter(df, x_column='PostalCode', y_column='TotalClaims')

# %%
# plot histogram
plot_histogram(df, column='TotalPremium')

# %%
# plot histogram for TotalClaims
plot_histogram(df, column='TotalClaims')

# %%
# plot histogram for PostalCode
plot_histogram(df, column='PostalCode')
